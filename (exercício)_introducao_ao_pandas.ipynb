# %% [markdown]
# <a href="https://colab.research.google.com/github/karolinefarias/data-science-basico/blob/main/(exerc%C3%ADcio)_introducao_ao_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício - Introdução ao pandas
#
# dataset para exercício:
# [https://drive.google.com/file/d/17yQnpFJFhlGj-TW4YLRTBBov0TkFxzkx/view?usp=sharing]

# %% [markdown]
# ## Exercício 1: A partir do conjunto de dados fornecido, imprima as primeiras e últimas cinco linhas.
#
# ```Saída esperada:```
#
# ![image.png](data:image/png;base64,...)
#
# 5 primeiras linhas
#
# ![image.png](data:image/png;base64,...)
#
# 5 últimas linhas

# %% [markdown]
# ## Exercício 2: Limpe o conjunto de dados e atualize o arquivo CSV. Substitua todos os valores das colunas que contenham ?, n.a ou NaN.

# %% [markdown]
# ## Exercício 3: Encontre o nome da empresa de carros mais caro. Imprima o nome da empresa de carros mais caro e o preço.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 4: Imprima os detalhes de todos os carros da Toyota.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 5: Contar o total de carros por empresa.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 6: Encontre o carro mais caro de cada empresa.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 7: Encontre a quilometragem média de cada fabricante de carro.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 8: Ordene todos os carros pela coluna de Preço.
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 9: Concatene dois dataframes usando as seguintes condições.
#
# Crie dois dataframes usando os seguintes dois dicionários.
#
# ```
# GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
# japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
#
# ```
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 10: Fundir dois dataframes usando a seguinte condição
#
# Criar dois DataFrames usando os seguintes dois dicionários, mesclar os dois DataFrames e anexar o segundo DataFrame como uma nova coluna ao primeiro DataFrame.
#
# ```
# Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
# car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
# ```
#
# Saída esperada:
#
# ![image.png](data:image/png;base64,...)
